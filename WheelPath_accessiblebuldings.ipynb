# %%
# import Library
import pandas as pd

# %%
# read source csv
# rename the downloaded csv as per your ease, Here we have renamed downloaded csv as build
df = pd.read_csv("build.csv")

# rename description column
df['Details'] = df['Accessibility type description']

# drop unwanted columns
df = df.drop(['CLUE small area', 'Construction year','Refurbished year', 'x coordinate','y coordinate','Accessibility type'
              ,'Has showers', 'Number of floors (above ground)', 'Bicycle spaces','Building name','Accessibility type description'], axis=1)

# Sort data by Census year, since we need the latest year data
df = df.sort_values(by=['Census year','Block ID', 'Property ID', 'Base property ID'])

# %%
# keeping the first observation because the first 1 reflects the csv observations which i believe are more accurate
df.drop(df[df.duplicated(['Block ID', 'Base property ID'], keep='last')== True].index, inplace=True)

# resetting the index
df = df.reset_index()
df.drop(['index'], inplace=True, axis=1)

# %%
# remove the brackets from the location variable
df['Location'] = df['Location'].map(lambda x: str(x)[:-1])
df['Location'] = df['Location'].map(lambda x: str(x)[1:])

# %%
# Derive latitude from location and convert it to numeric
df['Latitude'] = df['Location'].str.split(',').str[0]
df = df[df['Latitude'] != "a"]
df['Latitude'] = df['Latitude'].astype('float64')

# %%
# Derive Longitude from location and convert it to numeric
df['Longitude'] = df['Location'].str.split(',').str[1]
df['Longitude'] = df['Longitude'].astype('float64')

# %%
# drop unwanted columns
df = df.drop(['Block ID', 'Property ID', 'Base property ID','Location','Census year'], axis=1)

# %%
# drop unwanted records
df = df[df['Predominant space use'] != "House/Townhouse"]
df = df[df['Predominant space use'] != "Unoccupied - Unused"]
df = df[df['Predominant space use'] != "Unoccupied - Under Renovation"]
df = df[df['Predominant space use'] != "Unoccupied - Under Construction"]
df = df[df['Predominant space use'] != "Unoccupied - Under Demolition/Condemned"]
df = df[df['Predominant space use'] != "Hospital/Clinic"]
df = df[df['Predominant space use'] != "Manufacturing"]
df = df[df['Predominant space use'] != "Storage"]
df = df[df['Predominant space use'] != "Parking - Private Covered"]
df = df[df['Predominant space use'] != "Parking - Commercial Covered"]

# %%
# Derive accessibility/ disabled flag
df['Accessibility rating'] = df['Accessibility rating'].astype('str')

df = df.rename(index=str, columns={'Street address':'SA','Predominant space use':'ttype','Accessibility rating':'DisableFlag'})

df['DisableFlag'] =df['DisableFlag'].str.replace('0.0','No')
df['DisableFlag'] =df['DisableFlag'].str.replace('1.0','No')
df['DisableFlag'] =df['DisableFlag'].str.replace('2.0','Yes')
df['DisableFlag'] =df['DisableFlag'].str.replace('3.0','Yes')
df = df[df['DisableFlag'] != "nan"]
df = df.fillna("Blank_tobereplaced")

# %%
# derive primary key for the json file
df = df.reset_index()
df['PrimaryKey'] = df.index + 1
df['PrimaryKey'] = "B"+df.PrimaryKey.map(str)

df['Description'] = df.SA.map(str)
df['Category'] = df.ttype
df['Description'] =df['Description'].str.replace(' : Blank_tobereplaced','')

# clean the descriptions, handle blanks
df['Description1'] = df['Description'].str.rstrip('-').str.split('-').str[1]
df.fillna("Blank_tobereplaced", inplace=True)
for i in range(len(df)):  
    if df['Description1'][i] != "Blank_tobereplaced":  
        df['Description'][i] = df['Description1'][i]
# Out:
# C:\Users\RakeshOM\AppData\Local\Continuum\anaconda2\lib\site-packages\ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app

# %%
# drop unwanted columns
df = df.drop(['SA','ttype','index', 'Description1'], axis=1)

# reorder columns
df = df[['PrimaryKey', 'Category','Description', 'Latitude', 'Longitude', 'DisableFlag','Details']]

# %%
j = df.set_index('PrimaryKey').to_json(orient='index')

# %%
# save the dataframe to JSON file
with open("accessible_building.json", "w") as text_file:
    text_file.write("{}".format(j))

# %%
df
# Out:
#      PrimaryKey                               Category  \
# 0            B1      Entertainment/Recreation - Indoor
# 1            B2                              Transport
# 2            B3                                 Office
# 3            B4                  Residential Apartment
# 4            B5                                 Office
# 5            B6                  Residential Apartment
# 6            B7                  Residential Apartment
# 7            B8                  Residential Apartment
# 8            B9                                 Office
# 9           B10                  Student Accommodation
# 10          B11                        Workshop/Studio
# 11          B12                  Residential Apartment
# 12          B13                        Workshop/Studio
# 13          B14                 Equipment Installation
# 14          B15                                 Office
# 15          B16                 Equipment Installation
# 16          B17                 Equipment Installation
# 17          B18               Commercial Accommodation
# 18          B19                 Equipment Installation
# 19          B20                          Community Use
# 20          B21                          Retail - Shop
# 21          B22                  Residential Apartment
# 22          B23                                 Office
# 23          B24                          Community Use
# 24          B25                  Residential Apartment
# 25          B26                          Community Use
# 26          B27                  Residential Apartment
# 27          B28                  Residential Apartment
# 28          B29                 Equipment Installation
# 29          B30                 Equipment Installation
# ...         ...                                    ...
# 4102      B4103                                 Office
# 4103      B4104                                 Office
# 4104      B4105                                 Office
# 4105      B4106                        Workshop/Studio
# 4106      B4107                                 Office
# 4107      B4108  Performances, Conferences, Ceremonies
# 4108      B4109                                 Office
# 4109      B4110                  Residential Apartment
# 4110      B4111                  Residential Apartment
# 4111      B4112                  Residential Apartment
# 4112      B4113                  Residential Apartment
# 4113      B4114                        Workshop/Studio
# 4114      B4115                        Workshop/Studio
# 4115      B4116                                 Office
# 4116      B4117      Entertainment/Recreation - Indoor
# 4117      B4118                                 Office
# 4118      B4119                        Workshop/Studio
# 4119      B4120                 Equipment Installation
# 4120      B4121                                 Office
# 4121      B4122                  Residential Apartment
# 4122      B4123                  Residential Apartment
# 4123      B4124                        Workshop/Studio
# 4124      B4125                        Workshop/Studio
# 4125      B4126                        Workshop/Studio
# 4126      B4127      Entertainment/Recreation - Indoor
# 4127      B4128                        Workshop/Studio
# 4128      B4129                        Workshop/Studio
# 4129      B4130                   Educational/Research
# 4130      B4131                                 Office
# 4131      B4132                        Workshop/Studio
# 4123        14 Thompson Street -37.792512  144.934407          No
# 4124           74 Smith Street -37.791947  144.934880          No
# 4125         470 Macaulay Road -37.794402  144.931270          No
# 4126          173 Rankins Road -37.794362  144.931113         Yes
# 4127         456 Macaulay Road -37.794369  144.931544          No
# 4128         444 Macaulay Road -37.794441  144.932147          No
# 4129       76 Robertson Street -37.793465  144.933544          No
# 4130         400 Macaulay Road -37.794201  144.933761          No
# 4131         350 Macaulay Road -37.794224  144.934543         Yes
#
#                                                 Details
# 0                              All entrances have steps
# 1     Configuration of entrance does not fit into an...
# 2                              All entrances have steps
# 3                              All entrances have steps
# 4                                Main Entrance has ramp
# 5     Main Entrance is at grade and has no steps or ...
# 6                              All entrances have steps
# 7                              All entrances have steps
# 8     Entrance(s) have limited access via a small li...
# 9                              All entrances have steps
# 10    Building is not considered to be publicly acce...
# 11    Building is not considered to be publicly acce...
# 12    Building is not considered to be publicly acce...
# 13    Building is not considered to be publicly acce...
# 14    Main Entrance is at grade and has no steps or ...
# 15    Building is not considered to be publicly acce...
# 16    Configuration of entrance does not fit into an...
# 17    Main Entrance is at grade and has no steps or ...
# 18    Building is not considered to be publicly acce...
# 19    Building is not considered to be publicly acce...
# 20    Configuration of entrance does not fit into an...
# 21                             All entrances have steps
# 22                             All entrances have steps
# 23                             All entrances have steps
# 24    Building is not considered to be publicly acce...
# 25    Building is not considered to be publicly acce...
# 26    Building is not considered to be publicly acce...
# 27    Building is not considered to be publicly acce...
# 28    Building is not considered to be publicly acce...
# 29    Building is not considered to be publicly acce...
# ...                                                 ...
# 4102                             Main Entrance has ramp
# 4103                           All entrances have steps
# 4104                           All entrances have steps
# 4105  Entrance(s) have limited access via a small li...
# 4106                           All entrances have steps
# 4107  Entrance(s) have limited access via a small li...
# 4108  Main Entrance is at grade and has no steps or ...
# 4109  Building is not considered to be publicly acce...
# 4110  Configuration of entrance does not fit into an...
# 4111  Building is not considered to be publicly acce...
# 4112  Building is not considered to be publicly acce...
# 4113  Configuration of entrance does not fit into an...
# 4114  Configuration of entrance does not fit into an...
# 4115                           All entrances have steps
# 4116                           All entrances have steps
# 4117  Main Entrance is at grade and has no steps or ...
# 4118  Building is not considered to be publicly acce...
# 4119  Building is not considered to be publicly acce...
# 4120  Entrance(s) have limited access via a small li...
# 4121  Main Entrance is at grade and has no steps or ...
# 4122  Main Entrance is at grade and has no steps or ...
# 4123                           All entrances have steps
# 4124                           All entrances have steps
# 4125                           All entrances have steps
# 4126  Entrance(s) have limited access via a small li...
# 4127                           All entrances have steps
# 4128                           All entrances have steps
# 4129                           All entrances have steps
# 4130  Building is not considered to be publicly acce...
# 4131                             Main Entrance has ramp
#
# [4132 rows x 7 columns]
